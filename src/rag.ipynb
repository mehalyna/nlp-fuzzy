# %% [markdown]
# # RAG System

# %%
import tiktoken
from langchain_openai import OpenAIEmbeddings
import numpy as np
import bs4
from langchain_community.document_loaders import WebBaseLoader

import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = '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'

open_api_key = ''

os.environ['OPENAI_API_KEY'] = open_api_key
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# Documents
question = "What kinds of pets do I like?"
document = "My favorite pet is a cat."

# %% [markdown]
# Count tokens

# %%
import tiktoken

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_tokens_from_string(question, "cl100k_base")
# Out:
# 8

# %%
from langchain_openai import OpenAIEmbeddings
embd = OpenAIEmbeddings()
query_result = embd.embed_query(question)
document_result = embd.embed_query(document)
len(query_result)
# Out:
# 1536

# %%
print(query_result)
# Out:
# [-0.0035892894957214594, -0.0030708718113601208, -0.012454708106815815, -0.024972829967737198, -0.028308460488915443, 0.01755327545106411, -0.01554935984313488, -0.008535659871995449, -0.006747357081621885, -0.00487027270719409, -0.003703436581417918, 0.005456861574202776, -0.008351756259799004, -0.001444276887923479, 0.009429811500012875, 0.01955718919634819, 0.03076896257698536, 0.01491521019488573, 0.01570155657827854, -0.015473262406885624, -0.016107412055134773, 3.998118336312473e-05, 0.006664917338639498, -0.024389412254095078, -0.01263861171901226, -0.0032151408959180117, 0.011941046454012394, -0.0013158614747226238, -0.018124010413885117, -0.015815703198313713, 0.051188595592975616, -0.0031025793869048357, -0.022880135104060173, -0.01207421813160181, 0.0022005008067935705, 0.002760138362646103, 0.01438252441585064, 0.004844906739890575, 0.013608860783278942, 0.00035928565193898976, -0.0013491542777046561, 0.020952319726347923, 0.01562545821070671, -0.0045151486992836, 0.014052766375243664, 0.01214397419244051, -0.013355201110243797, 0.005542472004890442, -0.015168869867920876, -0.012403976172208786, 0.011389335617423058, -0.021878177300095558, -0.02166256681084633, 0.003690753597766161, -0.00954395905137062, 0.0022385497577488422, -0.012118608690798283, 0.004432708956301212, 0.00635418388992548, -0.009810301475226879, 0.0180605947971344, 0.020673293620347977, -0.017198150977492332, 0.014458621852099895, -0.0067410157062113285, 0.0031216037459671497, 0.01052689179778099, 0.011154700070619583, -0.0004930517170578241, -0.01045079343020916, 0.0053300317376852036, -0.00741955591365695, 0.004261488560587168, 0.005551984068006277, 0.01988694630563259, -0.0028314802329987288, 0.006389062386006117, 0.013342518359422684, -0.0060339379124343395, -0.01143372617661953, 0.01683034375309944, -0.027902603149414062, -0.029805054888129234, 0.008421513251960278, 0.01329178549349308, 0.02047036588191986, 0.012086900882422924, 0.009315664879977703, 0.0005148506024852395, 0.0010511038126423955, 0.018124010413885117, 0.020077191293239594, 0.013431298546493053, 0.016107412055134773, 0.01842840202152729, 0.005850034765899181, -0.0090302973985672, -0.016551317647099495, -0.007952242158353329, -0.03688216954469681, -0.004711735062301159, 0.0028679438401013613, -0.02749674767255783, -0.00785077828913927, 0.0018739135703071952, -0.011275188997387886, 0.0008299439214169979, -0.01143372617661953, 0.02942456491291523, -0.013152273371815681, -0.020305486395955086, 0.035157281905412674, 0.03371141850948334, -0.052710555493831635, -0.005260275211185217, -0.003040749579668045, 0.009391763247549534, -0.002676113275811076, -0.01023518294095993, 0.009360055439174175, 0.01425569411367178, 0.013697641901671886, 0.037668514996767044, -0.020153289660811424, 0.032569948583841324, 0.025302588939666748, -0.0010962869273498654, -0.01901181973516941, -0.011535190045833588, -0.0016773269744589925, 0.03662851080298424, 0.015574726276099682, 0.015371798537671566, 0.007495654281228781, -0.036806073039770126, 0.011459092609584332, -0.02567039616405964, 0.007736631203442812, 0.01653863489627838, -0.01679229363799095, -0.014991308562457561, 0.03277287632226944, 0.002810870297253132, -0.002823553280904889, 0.015638140961527824, 0.02490941621363163, 0.029526028782129288, -0.012885930016636848, 0.006557112094014883, 0.004125146195292473, 0.0069883340038359165, -0.0050636883825063705, 0.0354616716504097, -0.003145384369418025, -0.014116181060671806, 0.00010671556810848415, -0.031301647424697876, 0.017756203189492226, -0.00590076670050621, -0.012828856706619263, 0.017248881980776787, -0.009715178981423378, 0.020749390125274658, 0.006252720020711422, 0.003995145671069622, 0.04999639466404915, 0.044593434780836105, 0.028486022725701332, -0.01088835671544075, 0.009290298447012901, -0.017020588740706444, 0.013520079664885998, -0.0203181691467762, 0.033863615244627, -0.016995223239064217, 0.012809831649065018, -0.005881742108613253, -0.012917637825012207, -0.0125815374776721, -0.002 ...

# %% [markdown]
# Cosine Similarity

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

similarity = cosine_similarity(query_result, document_result)
print("Cosine Similarity:", similarity)
# Out:
# Cosine Similarity: 0.8806915835035412

# %% [markdown]
# Retrieval (documents in vector space) augmented generation (llm)

# %%
#### INDEXING ####

# Load blog
import bs4
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(
    web_paths=("https://mathmod.chnu.edu.ua/",)
    # bs_kwargs=dict(
    #     parse_only=bs4.SoupStrainer(
    #         class_=("post-content", "post-title", "post-header")
    #     )
    # ),
)
blog_docs = loader.load()

# %%
# Split
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=300, 
    chunk_overlap=50)

# Make splits
splits = text_splitter.split_documents(blog_docs)
print(splits)

# splits = blog_docs.split(' ')
# print(splits)
# Out:
# [Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Кафедра математичного моделювання - Кафедра математичного моделювання\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nПерейти до основного вмісту\n\n\n\n\n\n\n[email\xa0protected]\n\n\n\r\n                 вул. Університетська 28, каб. 17\r\n            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nНовини\n\nПро нас'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Новини\n\nПро нас\n\n\nІсторія\nСпівробітники\nНауково-дослідна робота\nПублікації\nКафедральні дисципліни\nСпівпраця\nМіжнародна діяльність\nАспірантура\n\n\n\n\nОсвітні програми'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Освітні програми\n\n\nОП "Інформаційні технології та управління проєктами" (бакалавр)\nОП "Інформаційні технології та управління проєктами" (магістр)\nОП "Системний аналіз" (бакалавр)\nОП "Системний аналіз" (магістр)\n\n\n\n\nСтуденту'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Студенту\n\n\nАкадемічна доброчесність\nРозклад занять\nНавчальні плани\nРобочі програми дисциплін\nГуртки\nНауково-дослідна робота студентів\nКурсові та кваліфікаційні роботи\nПрактична підготовка\n\n\n\n\nАбітурієнту'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content="Приймальна комісія ЧНУ\nДень відкритих дверей (презентація)\nНМТ 2024 Демонстраційний варіант\nЗразки мотиваційних листів\nПрограма фахового іспиту для бакалаврів Комп'ютерних наук (скорочена форма навчання)"), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Програма предметного тесту з інформаційних технологій (магістратура)'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Онлайн школа\n\n\nПлан занять\nРеєстрація\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nКафедра математичного моделювання'), Document(metadata={'source': 'https://mathmod.chnu.edu.ua/', 'title': 'Кафедра математичного моделювання - Кафедра математичного моделювання', 'description': 'Офіційна сторінка кафедри математичного моделювання Чернівецького національного університету імені Юрія Федьковича', 'language': 'uk'}, page_content='Факультет математики та інформатики\nКафедра математичного моделювання'), Doc ...

# %%
# Index
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
vectorstore = Chroma.from_documents(documents=splits, 
                                    embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
